# %%
import sys
sys.path.append("/scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages")
sys.path.append("/scratch/group/csce435-f24/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
tk1 = th.Thicket.from_caliperreader(glob("final_cali/p128-a28-random.cali"))
tk2 = th.Thicket.from_caliperreader(glob("final_cali/p8-a22-random.cali"))
tk3 = th.Thicket.from_caliperreader(glob("final_cali/p128-a22-random.cali"))
# Out:
# (1/2) Reading Files: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.16it/s]
# 0it [00:00, ?it/s]
# (1/2) Reading Files: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 28.74it/s]
# 0it [00:00, ?it/s]
# (1/2) Reading Files: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 26.50it/s]
# 0it [00:00, ?it/s]

# %%
tk1 = th.Thicket.from_caliperreader(glob("final_cali/p256-a28-random.cali"))
print(tk1.tree(metric_column="Max time/rank"))
# Out:
# (1/2) Reading Files: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 27.51it/s]
# 0it [00:00, ?it/s]
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 10.808 main
# ├─ 1.430 MPI_Comm_dup
# ├─ 0.000 MPI_Comm_free
# ├─ 0.000 MPI_Finalize
# ├─ 0.000 MPI_Finalized
# ├─ 0.000 MPI_Initialized
# ├─ 8.013 comm
# │  ├─ 7.231 comm_large
# │  │  ├─ 0.670 MPI_Alltoallv
# │  │  ├─ 0.945 MPI_Gatherv
# │  │  └─ 5.636 MPI_Scatter
# │  └─ 1.711 comm_small
# │     ├─ 0.482 MPI_Alltoall
# │     ├─ 0.439 MPI_Bcast
# │     └─ 1.240 MPI_Gather
# ├─ 3.599 comp
# │  ├─ 3.599 comp_large
# │  └─ 0.024 comp_small
# ├─ 0.779 correctness_check
# └─ 5.502 data_init_runtime
#
# Legend (Metric: Max time/rank Min: 0.00 Max: 10.81 indices: {'profile': 889657943})
# █ 9.73 - 10.81
# █ 7.57 - 9.73
# █ 5.40 - 7.57
# █ 3.24 - 5.40
# █ 1.08 - 3.24
# █ 0.00 - 1.08
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
print(tk1.metadata)
# Out:
#           cali.caliper.version  mpi.world.size  \
# profile
# 889657943               2.11.0             256
#
#                                                 spot.metrics  \
# profile
# 889657943  min#inclusive#sum#time.duration,max#inclusive#...
#
#           spot.timeseries.metrics  spot.format.version  \
# profile
# 889657943                                            2
#
#                                                 spot.options  spot.channels  \
# profile
# 889657943  time.variance,profile.mpi,node.order,region.co...  regionprofile
#
#           cali.channel spot:node.order           spot:output spot:profile.mpi  \
# profile
# 889657943         spot            true  p256-a28-Random.cali             true
#
#           spot:region.count spot:time.exclusive spot:time.variance  \
# profile
# 889657943              true                true               true
#
#            launchdate                                          libraries  \
# profile
# 889657943  1729838374  [/scratch/group/csce435-f24/Caliper/caliper/li...
#
#                               cmdline cluster algorithm programming_model  \
# profile
# 889657943  [./samplesort, 28, Random]       c    Sample               MPI
#
#           data_type  size_of_data_type  input_size input_type scalability  \
# profile
# 889657943         I                  4   268435456     Random      strong
#
#            group_num implementation_source
# profile
# 889657943          9                online

# %%
print(tk2.tree(metric_column="Max time/rank"))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 0.567 main
# ├─ 0.048 MPI_Comm_dup
# ├─ 0.000 MPI_Comm_free
# ├─ 0.000 MPI_Finalize
# ├─ 0.000 MPI_Finalized
# ├─ 0.000 MPI_Initialized
# ├─ 0.284 comm
# │  ├─ 0.112 comm_large
# │  │  ├─ 0.005 MPI_Alltoallv
# │  │  ├─ 0.020 MPI_Gatherv
# │  │  └─ 0.092 MPI_Scatter
# │  └─ 0.263 comm_small
# │     ├─ 0.001 MPI_Alltoall
# │     ├─ 0.003 MPI_Bcast
# │     └─ 0.263 MPI_Gather
# ├─ 0.413 comp
# │  ├─ 0.413 comp_large
# │  └─ 0.000 comp_small
# ├─ 0.012 correctness_check
# └─ 0.086 data_init_runtime
#
# Legend (Metric: Max time/rank Min: 0.00 Max: 0.57 indices: {'profile': 3964702012})
# █ 0.51 - 0.57
# █ 0.40 - 0.51
# █ 0.28 - 0.40
# █ 0.17 - 0.28
# █ 0.06 - 0.17
# █ 0.00 - 0.06
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
print(tk3.tree(metric_column="Max time/rank"))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 0.504 main
# ├─ 0.213 MPI_Comm_dup
# ├─ 0.000 MPI_Comm_free
# ├─ 0.000 MPI_Finalize
# ├─ 0.000 MPI_Finalized
# ├─ 0.000 MPI_Initialized
# ├─ 0.265 comm
# │  ├─ 0.220 comm_large
# │  │  ├─ 0.065 MPI_Alltoallv
# │  │  ├─ 0.063 MPI_Gatherv
# │  │  └─ 0.107 MPI_Scatter
# │  └─ 0.110 comm_small
# │     ├─ 0.047 MPI_Alltoall
# │     ├─ 0.036 MPI_Bcast
# │     └─ 0.056 MPI_Gather
# ├─ 0.055 comp
# │  ├─ 0.055 comp_large
# │  └─ 0.005 comp_small
# ├─ 0.012 correctness_check
# └─ 0.086 data_init_runtime
#
# Legend (Metric: Max time/rank Min: 0.00 Max: 0.50 indices: {'profile': 1548238663})
# █ 0.45 - 0.50
# █ 0.35 - 0.45
# █ 0.25 - 0.35
# █ 0.15 - 0.25
# █ 0.05 - 0.15
# █ 0.00 - 0.05
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk = th.Thicket.from_caliperreader(glob("final_cali/*.cali"))
# Out:
# (1/2) Reading Files: 100%|███████████████████████████████████████████████████████████| 219/219 [00:08<00:00, 26.61it/s]
# (2/2) Creating Thicket: 100%|███████████████████████████████████████████████████████| 218/218 [00:02<00:00, 107.91it/s]

# %%
tk.metadata_column_to_perfdata("mpi.world.size")
tk.metadata_column_to_perfdata("input_size")
tk.metadata_column_to_perfdata("input_type")

df = tk.dataframe.reset_index()
df.head()
# Out:
#                                    node   profile  nid   spot.channel  \
# 0  {'name': 'main', 'type': 'function'}  36119720  1.0  regionprofile
# 1  {'name': 'main', 'type': 'function'}  41841080  1.0  regionprofile
# 2  {'name': 'main', 'type': 'function'}  78733441  1.0  regionprofile
# 3  {'name': 'main', 'type': 'function'}  84856842  1.0  regionprofile
# 4  {'name': 'main', 'type': 'function'}  94270458  1.0  regionprofile
#
#    Min time/rank  Max time/rank  Avg time/rank   Total time  \
# 0       2.344176       2.344190       2.344184    18.753469
# 1      16.770774      16.773469      16.772122    33.544243
# 2       0.224518       0.238892       0.233316     7.466103
# 3       7.019581       7.136060       7.106540  1819.274219
# 4       0.159812       0.310061       0.284204    36.378070
#
#    Variance time/rank  Min time/rank (exc)  Max time/rank (exc)  \
# 0            0.000000             0.010812             0.021285
# 1            0.000002             0.259738             0.260616
# 2            0.000005             0.001280             0.001582
# 3            0.000315             0.008622             0.019815
# 4            0.001073             0.000174             0.000308
#
#    Avg time/rank (exc)  Total time (exc)  Calls/rank (min)  Calls/rank (avg)  \
# 0             0.018856          0.150846               NaN               NaN
# 1             0.260177          0.520354               NaN               NaN
# 2             0.001531          0.048984               NaN               NaN
# 3             0.009686          2.479677               NaN               NaN
# 4             0.000195          0.024902               NaN               NaN
#
#    Calls/rank (max)  Calls/rank (total)  name  mpi.world.size  input_size  \
# 0               NaN                 NaN  main               8    16777216
# 1               NaN                 NaN  main               2    67108864
# 2               NaN                 NaN  main              32     4194304
# 3               NaN                 NaN  main             256   268435456
# 4               NaN                 NaN  main             128       65536
#
#   input_type
# 0     Random
# 1     Sorted
# 2  Perturbed
# 3     Sorted
# 4    Reverse

# %%
import math

# %%
def plot_large_data(df, name, ax, input_type):
    df_filtered = df[(df["input_type"] == input_type) & (df["name"] == name)]
    
    df_22 = df_filtered[df_filtered["input_size"] == math.pow(2, 24)].sort_values("mpi.world.size")
    df_24 = df_filtered[df_filtered["input_size"] == math.pow(2, 26)].sort_values("mpi.world.size")
    df_26 = df_filtered[df_filtered["input_size"] == math.pow(2, 28)].sort_values("mpi.world.size")
    
    df_22.plot(x="mpi.world.size", y="Avg time/rank", ax=ax, label="Input size: 2^24")
    df_24.plot(x="mpi.world.size", y="Avg time/rank", ax=ax, label="Input size: 2^26")
    df_26.plot(x="mpi.world.size", y="Avg time/rank", ax=ax, label="Input size: 2^28")
    
    ax.set_xscale('log', base=2)
    ax.set_title(f"{name}")
    ax.set_xlabel("Number of Processes")
    ax.set_ylabel("Avg time/rank")
    ax.legend()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

plot_large_data(df, "comm", ax1, "Random")
plot_large_data(df, "comp_large", ax2, "Random")
plot_large_data(df, "main", ax3, "Random")

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

plot_large_data(df, "comm", ax1, "Sorted")
plot_large_data(df, "comp_large", ax2, "Sorted")
plot_large_data(df, "main", ax3, "Sorted")

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

plot_large_data(df, "comm", ax1, "Reverse")
plot_large_data(df, "comp_large", ax2, "Reverse")
plot_large_data(df, "main", ax3, "Reverse")

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

plot_large_data(df, "comm", ax1, "Perturbed")
plot_large_data(df, "comp_large", ax2, "Perturbed")
plot_large_data(df, "main", ax3, "Perturbed")

plt.tight_layout()
plt.show()

# %%
def plot_small_data(df, name, ax, input_type):
    df_filtered = df[(df["input_type"] == input_type) & (df["name"] == name)]
    
    df_16 = df_filtered[df_filtered["input_size"] == math.pow(2, 16)].sort_values("mpi.world.size")
    df_18 = df_filtered[df_filtered["input_size"] == math.pow(2, 18)].sort_values("mpi.world.size")
    df_20 = df_filtered[df_filtered["input_size"] == math.pow(2, 20)].sort_values("mpi.world.size")
    
    df_16.plot(x="mpi.world.size", y="Avg time/rank", ax=ax, label="Input size: 2^16")
    df_18.plot(x="mpi.world.size", y="Avg time/rank", ax=ax, label="Input size: 2^18")
    df_20.plot(x="mpi.world.size", y="Avg time/rank", ax=ax, label="Input size: 2^20")
    
    ax.set_xscale('log', base=2)
    ax.set_title(f"{name}")
    ax.set_xlabel("Number of Processes")
    ax.set_ylabel("Avg time/rank")
    ax.legend()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

plot_small_data(df, "comm", ax1, "Random")
plot_small_data(df, "comp_large", ax2, "Random")
plot_small_data(df, "main", ax3, "Random")

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

plot_small_data(df, "comm", ax1, "Sorted")
plot_small_data(df, "comp_large", ax2, "Sorted")
plot_small_data(df, "main", ax3, "Sorted")

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

plot_small_data(df, "comm", ax1, "Reverse")
plot_small_data(df, "comp_large", ax2, "Reverse")
plot_small_data(df, "main", ax3, "Reverse")

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

plot_small_data(df, "comm", ax1, "Perturbed")
plot_small_data(df, "comp_large", ax2, "Perturbed")
plot_small_data(df, "main", ax3, "Perturbed")

plt.tight_layout()
plt.show()

# %%
def algorithm_comparison(df, ax, array_size, name):
    df_filtered = df[(df["input_size"] == math.pow(2, array_size)) & (df["name"] == name)]

    implementations = ["Random", "Sorted", "Reverse", "Perturbed"]

    for i in implementations:
        df_ = df_filtered[df_filtered["input_type"] == i].sort_values("mpi.world.size")
        df_.plot(x="mpi.world.size", y="Avg time/rank", ax=ax, label=f"{i}")
    
    ax.set_xscale('log', base=2)
    ax.set_title(f"{name} time for Array size: 2^{array_size}")
    ax.set_xlabel("Number of Processes")
    ax.set_ylabel("Avg time/rank")
    ax.legend()

# %%
# Comparing runtimes of different input types

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

algorithm_comparison(df, ax1, 28, "comm")
algorithm_comparison(df, ax2, 28, "comp_large")
algorithm_comparison(df, ax3, 28, "main")

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

algorithm_comparison(df, ax1, 16, "comm")
algorithm_comparison(df, ax2, 16, "comp_large")
algorithm_comparison(df, ax3, 16, "main")

plt.tight_layout()
plt.show()
